# %% [markdown]
# # ¡Hola!
#
# Mi nombre es Ezequiel Ferrario, soy code reviewer en Tripleten y tengo el agrado de revisar el proyecto que entregaste.
#
# Para simular la dinámica de un ambiente de trabajo, si veo algún error, en primer instancia solo los señalaré, dándote la oportunidad de encontrarlos y corregirlos por tu cuenta. En un trabajo real, el líder de tu equipo hará una dinámica similar. En caso de que no puedas resolver la tarea, te daré una información más precisa en la próxima revisión.
#
# Encontrarás mis comentarios más abajo - **por favor, no los muevas, no los modifiques ni los borres**.
#
# ¿Cómo lo voy a hacer? Voy a leer detenidamente cada una de las implementaciones que has llevado a cabo para cumplir con lo solicitado. Verás los comentarios de esta forma:
#
# <div class="alert alert-block alert-success">
# <b>Comentario del revisor</b> <a class="tocSkip"></a>
#
# Si todo está perfecto.
# </div>
#
#
# <div class="alert alert-block alert-warning">
# <b>Comentario del revisor</b> <a class="tocSkip"></a>
#
# Si tu código está bien pero se puede mejorar o hay algún detalle que le hace falta. Se aceptan uno o dos comentarios de este tipo en el borrador, pero si hay más, deberá hacer las correcciones. Es como una tarea de prueba al solicitar un trabajo: muchos pequeños errores pueden hacer que un candidato sea rechazado.
# </div>
#
# <div class="alert alert-block alert-danger">
#
# <b>Comentario del revisor</b> <a class="tocSkip"></a>
#
# Si de pronto hace falta algo o existe algún problema con tu código o conclusiones.
# </div>
#
# Puedes responderme de esta forma:
#
# <div class="alert alert-block alert-info">
# <b>Respuesta del estudiante</b> <a class="tocSkip"></a>
#
# Hola, muchas gracias por tus comentarios y la revisión.
# </div>
#
# ¡Empecemos!

# %% [markdown]
# -------
#
# <div class="alert alert-block alert-danger">
#
# <b>Comentario general #1</b> <a class="tocSkip"></a>
#
# Hiciste un muy buen proyecto.
#
#  El trabajo es extenso pero supiste abarcarlo de excelente forma.
#
#   Limpiaste todos los dataset de buena manera, encontrando todas las inconsistencias y patrones.
#
#   Luego, generaste excelentes graficos y muy buenas extracciones. A su vez con todas tus observaciones fuiste agregando claridad a cada paso lo que agrego valor al proyecto.
#
#   Asi, restan algunos puntos minimos por corregir.
#
#   Quedo atento a tu correccion, saludos.
#
#
# </div>
#
# ----
#
# <div class="alert alert-block alert-success">
#
# <b>Comentario general #2</b> <a class="tocSkip"></a>
#
# Las correcciones han sido excelentes, abarcaste todos los detalles del trabajo y finalizas asi un excelente proyecto.
#
# Por todo lo dicho anteriormente, este trabajo pasa a estar **aprobado**.
#
# Exitos en lo que viene, saludos.</div>
#
# ----

# %% [markdown]
# # ¡Llena ese carrito!

# %% [markdown]
# <div class="alert alert-block alert-warning">
#
# <b>Comentario del revisor</b> <a class="tocSkip"></a>
#
# En este caso podes hacer una tabla de contenidos que este  linkeada a las secciones (al clickear debe llevarnos a esa seccion) de esta menera es mas facil desplazarse.
#
# Como consejo, si realizas bien todas las secciones (con su respectivo #) podes generarlo automáticamente desde jupyter lab. Para hacerlo, en la pestaña de herramientas de jupyter lab clickeas en el **botón de los puntos y barras**  (Table of contents) te generara automáticamente una tabla de contenidos linkeable y estética. A la **derecha** del seleccionador del tipo de celda (code/markdown)
# </div>
#
# <div class="alert alert-block alert-success">
#
# <b>Comentario del revisor ·2</b> <a class="tocSkip"></a>
#
# Corregido.
# </div>

# %% [markdown]
# <div class="alert alert-block alert-info">
# <b>Respuesta del estudiante</b> <a class="tocSkip"></a>
#
# Hola, ya vi como se genera dandole clic en View y en Table of Contents, gracias, es una manera sencilla de navegar.
# </div>

# %% [markdown]
# # Introducción
#
# Instacart es una plataforma de entregas de comestibles donde la clientela puede registrar un pedido y hacer que se lo entreguen, similar a Uber Eats y Door Dash.
# El conjunto de datos que te hemos proporcionado tiene modificaciones del original. Redujimos el tamaño del conjunto para que tus cálculos se hicieran más rápido e introdujimos valores ausentes y duplicados. Tuvimos cuidado de conservar las distribuciones de los datos originales cuando hicimos los cambios.
#
# Debes completar tres pasos. Para cada uno de ellos, escribe una breve introducción que refleje con claridad cómo pretendes resolver cada paso, y escribe párrafos explicatorios que justifiquen tus decisiones al tiempo que avanzas en tu solución.  También escribe una conclusión que resuma tus hallazgos y elecciones.

# %% [markdown]
# ## Diccionario de datos
#
# Hay cinco tablas en el conjunto de datos, y tendrás que usarlas todas para hacer el preprocesamiento de datos y el análisis exploratorio de datos. A continuación se muestra un diccionario de datos que enumera las columnas de cada tabla y describe los datos que contienen.
#
# - `instacart_orders.csv`: cada fila corresponde a un pedido en la aplicación Instacart.
#     - `'order_id'`: número de ID que identifica de manera única cada pedido.
#     - `'user_id'`: número de ID que identifica de manera única la cuenta de cada cliente.
#     - `'order_number'`: el número de veces que este cliente ha hecho un pedido.
#     - `'order_dow'`: día de la semana en que se hizo el pedido (0 si es domingo).
#     - `'order_hour_of_day'`: hora del día en que se hizo el pedido.
#     - `'days_since_prior_order'`: número de días transcurridos desde que este cliente hizo su pedido anterior.
# - `products.csv`: cada fila corresponde a un producto único que pueden comprar los clientes.
#     - `'product_id'`: número ID que identifica de manera única cada producto.
#     - `'product_name'`: nombre del producto.
#     - `'aisle_id'`: número ID que identifica de manera única cada categoría de pasillo de víveres.
#     - `'department_id'`: número ID que identifica de manera única cada departamento de víveres.
# - `order_products.csv`: cada fila corresponde a un artículo pedido en un pedido.
#     - `'order_id'`: número de ID que identifica de manera única cada pedido.
#     - `'product_id'`: número ID que identifica de manera única cada producto.
#     - `'add_to_cart_order'`: el orden secuencial en el que se añadió cada artículo en el carrito.
#     - `'reordered'`: 0 si el cliente nunca ha pedido este producto antes, 1 si lo ha pedido.
# - `aisles.csv`
#     - `'aisle_id'`: número ID que identifica de manera única cada categoría de pasillo de víveres.
#     - `'aisle'`: nombre del pasillo.
# - `departments.csv`
#     - `'department_id'`: número ID que identifica de manera única cada departamento de víveres.
#     - `'department'`: nombre del departamento.

# %% [markdown]
# # Paso 1. Descripción de los datos
#
# Lee los archivos de datos (`/datasets/instacart_orders.csv`, `/datasets/products.csv`, `/datasets/aisles.csv`, `/datasets/departments.csv` y `/datasets/order_products.csv`) con `pd.read_csv()` usando los parámetros adecuados para leer los datos correctamente. Verifica la información para cada DataFrame creado.

# %% [markdown]
# ## Plan de solución
#
# Escribe aquí tu plan de solución para el Paso 1. Descripción de los datos.
#
# Voy a importar la libreria pandas
# y usar el metodo read_csv para leer los conjuntos de datos, imprimirlos con el metodo .head() y verificar que separador utilizan para añadirlo en el metodo read_csv.

# %%
# importar librerías
import pandas as pd
import matplotlib.pyplot as plt

# %%
# leer conjuntos de datos en los DataFrames
df_instacart_orders = pd.read_csv('/datasets/instacart_orders.csv', sep=';')
df_products = pd.read_csv('/datasets/products.csv', sep=';')
df_aisles = pd.read_csv('/datasets/aisles.csv', sep=';')
df_departments = pd.read_csv('/datasets/departments.csv', sep=';')
df_order_products = pd.read_csv('/datasets/order_products.csv', sep=';')

# %%
print(df_instacart_orders.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 478967 entries, 0 to 478966
# Data columns (total 6 columns):
#  #   Column                  Non-Null Count   Dtype
# ---  ------                  --------------   -----
#  0   order_id                478967 non-null  int64
#  1   user_id                 478967 non-null  int64
#  2   order_number            478967 non-null  int64
#  3   order_dow               478967 non-null  int64
#  4   order_hour_of_day       478967 non-null  int64
#  5   days_since_prior_order  450148 non-null  float64
# dtypes: float64(1), int64(5)
# memory usage: 21.9 MB
# None

# %%
print(df_products.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 49694 entries, 0 to 49693
# Data columns (total 4 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   product_id     49694 non-null  int64
#  1   product_name   48436 non-null  object
#  2   aisle_id       49694 non-null  int64
#  3   department_id  49694 non-null  int64
# dtypes: int64(3), object(1)
# memory usage: 1.5+ MB
# None

# %%
print(df_aisles.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 134 entries, 0 to 133
# Data columns (total 2 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   aisle_id  134 non-null    int64
#  1   aisle     134 non-null    object
# dtypes: int64(1), object(1)
# memory usage: 2.2+ KB
# None

# %%
print(df_departments.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21 entries, 0 to 20
# Data columns (total 2 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   department_id  21 non-null     int64
#  1   department     21 non-null     object
# dtypes: int64(1), object(1)
# memory usage: 464.0+ bytes
# None

# %%
print(df_order_products.info(show_counts=True))
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4545007 entries, 0 to 4545006
# Data columns (total 4 columns):
#  #   Column             Non-Null Count    Dtype
# ---  ------             --------------    -----
#  0   order_id           4545007 non-null  int64
#  1   product_id         4545007 non-null  int64
#  2   add_to_cart_order  4544171 non-null  float64
#  3   reordered          4545007 non-null  int64
# dtypes: float64(1), int64(3)
# memory usage: 138.7 MB
# None

# %% [markdown]
# ## Conclusiones
#
# Escribe aquí tus conclusiones intermedias sobre el Paso 1. Descripción de los datos.
# 1) Instacart_orders -> la columna days_since_prior_order contiene algunos datos nulos y ademas no entiendo porque el tipo de datos es flotante, pienso que como enteros tambien podria funcionar para decir hace cuantos dias completos un usuario no realiza un pedido
# 2) Products -> La columna product_name tiene algunos datos faltantes
# 3) Aisles -> parece bien
# 4) departments -> todo bien
# 5) order_products -> hacen falta algunos datos en la columna add_to_cart_order
#
# Lo que sigue es revisar los duplicados y rellenar los valores ausentes

# %% [markdown]
# <div class="alert alert-block alert-success">
#
# <b>Comentario del revisor</b> <a class="tocSkip"></a>
#
# Excelentes conclusiones.
#
#
# </div>

# %% [markdown]
# # Paso 2. Preprocesamiento de los datos
#
# Preprocesa los datos de la siguiente manera:
#
# - Verifica y corrige los tipos de datos (por ejemplo, asegúrate de que las columnas de ID sean números enteros).
# - Identifica y completa los valores ausentes.
# - Identifica y elimina los valores duplicados.
#
# Asegúrate de explicar qué tipos de valores ausentes y duplicados encontraste, cómo los completaste o eliminaste y por qué usaste esos métodos. ¿Por qué crees que estos valores ausentes y duplicados pueden haber estado presentes en el conjunto de datos?

# %% [markdown]
# ## Plan de solución
#
# Escribe aquí tu plan para el Paso 2. Preprocesamiento de los datos.

# %% [markdown]
# ## Encuentra y elimina los valores duplicados (y describe cómo tomaste tus decisiones).

# %% [markdown]
# ### `orders` data frame

# %%
# Revisa si hay pedidos duplicados
n_duplicados = df_instacart_orders['order_id'].duplicated().sum()
print(f"Pedidos con order_id repetido: {n_duplicados}")
# Out:
# Pedidos con order_id repetido: 15

# %% [markdown]
# ¿Tienes líneas duplicadas? Si sí, ¿qué tienen en común? el order_id

# %%
# Basándote en tus hallazgos,
# Verifica todos los pedidos que se hicieron el miércoles a las 2:00 a.m.
df_mie_2am = df_instacart_orders[
    (df_instacart_orders['order_dow'] == 3) &
    (df_instacart_orders['order_hour_of_day'] == 2)
]

print(f"Pedidos el miércoles a las 2 a.m.: {len(df_mie_2am)} filas")
print(df_mie_2am)

n_duplicados_miercoles = df_mie_2am['order_id'].duplicated().sum()
print(f"Pedidos con order_id repetido el dia miercoles a las 2 a.m: {n_duplicados}")
# Out:
# Pedidos el miércoles a las 2 a.m.: 121 filas
#         order_id  user_id  order_number  order_dow  order_hour_of_day  \
# 4838     2766110   162084            41          3                  2
# 5156     2190225   138285            18          3                  2
# 15506     553049    58599            13          3                  2
# 18420     382357   120200            19          3                  2
# 24691     690242    77357             2          3                  2
# ...          ...      ...           ...        ...                ...
# 457013   3384021    14881             6          3                  2
# 458816    910166   164782            18          3                  2
# 459635   1680532   106435             6          3                  2
# 468324    222962    54979            59          3                  2
# 477526   2592344    46860            38          3                  2
#
#         days_since_prior_order
# 4838                      16.0
# ...

# %% [markdown]
# ¿Qué sugiere este resultado? Que todos los duplicados estan en este dia y a esta hora

# %%
# Elimina los pedidos duplicados
df_instacart_orders = df_instacart_orders.drop_duplicates().reset_index(drop=True)
print(df_instacart_orders)
# Out:
#         order_id  user_id  order_number  order_dow  order_hour_of_day  \
# 0        1515936   183418            11          6                 13
# 1        1690866   163593             5          5                 12
# 2        1454967    39980             4          5                 19
# 3        1768857    82516            56          0                 20
# 4        3007858   196724             2          4                 12
# ...          ...      ...           ...        ...                ...
# 478947   3210681     5617             5          1                 14
# 478948   3270802   112087             2          3                 13
# 478949    885349    82944            16          2                 11
# 478950    216274     4391             3          3                  8
# 478951   2071924     1730            18          1                 14
#
#         days_since_prior_order
# 0                         30.0
# 1                          9.0
# ...

# %% [markdown]
# <div class="alert alert-block alert-warning">
#
# <b>Comentario del revisor</b> <a class="tocSkip"></a>
#
# Luego de eliminar los duplicados, recorda reiniciar el indice tras la eliminación. Ya que el índice queda desordenado, dificultando manipulaciones. Al reiniciarlo, se obtiene un índice ordenado y se conserva el original en una nueva columna, preservando la integridad y facilitando futuras referencias . Recorda luego utilizar el parametro drop en true ya que de lo contrario te quedara el indice anterior como columna.
# </div>
#
# <div class="alert alert-block alert-success">
#
# <b>Comentario del revisor #2</b> <a class="tocSkip"></a>
#
# Corregido, excelente.
# </div>

# %% [markdown]
# <div class="alert alert-block alert-info">
# <b>Respuesta del estudiante</b> <a class="tocSkip"></a>
#
# Muchas gracias, no recordaba lo del indice
# </div>

# %%
# Vuelve a verificar si hay filas duplicadas
print("Filas duplicadas exactas:", df_instacart_orders.duplicated(keep=False).sum())
# Out:
# Filas duplicadas exactas: 0

# %%
# Vuelve a verificar únicamente si hay IDs duplicados de pedidos
print("order_id duplicados:", df_instacart_orders['order_id'].duplicated().sum())
# Out:
# order_id duplicados: 0

# %% [markdown]
# Describe brevemente tus hallazgos y lo que hiciste con ellos
#
# Tal vez hubo un error de duplicacion de pedidos el dia miercoles a las 2 a.m. tal vez un error en sistema o tal vez se importo dos veces ese bloque de datos

# %% [markdown]
# <div class="alert alert-block alert-success">
#
# <b>Comentario del revisor</b> <a class="tocSkip"></a>
#
# Muy bien tratados estos duplicados.
#
# </div>

# %% [markdown]
# ### `products` data frame

# %%
# Verifica si hay filas totalmente duplicadas
print("Filas duplicadas:", df_products.duplicated(keep=False).sum())
# Out:
# Filas duplicadas: 0

# %%
# Revisa únicamente si hay ID de productos duplicados
n_duplicados = df_products['product_id'].duplicated().sum()
print(f"Pedidos con product_id repetido: {n_duplicados}")
# Out:
# Pedidos con product_id repetido: 0

# %%
# Revisa únicamente si hay nombres duplicados de productos (convierte los nombres a letras mayúsculas para compararlos mejor)
mask_name_dups = df_products['product_name'].str.upper().duplicated(keep=False)
n_name_dups = mask_name_dups.sum()
print("duplicados (sin distinguir mayúsculas):", n_name_dups)
# Out:
# duplicados (sin distinguir mayúsculas): 1465

# %%
# Revisa si hay nombres duplicados de productos no faltantes
print(df_products[mask_name_dups].sort_values(by='product_name').head(10))
# Out:
#        product_id                               product_name  aisle_id  \
# 31844       31845  18-In-1 Hemp Peppermint Pure-Castile Soap        25
# 23339       23340  18-in-1 Hemp Peppermint Pure-Castile Soap        25
# 19941       19942            Aged Balsamic Vinegar Of Modena        19
# 13152       13153            Aged Balsamic Vinegar of Modena        19
# 22582       22583         Albacore Solid White Tuna In Water        95
# 24830       24831         Albacore Solid White Tuna in Water        95
# 515           516                     American Cheese Slices        21
# 9037         9038                     American Cheese slices        21
# 49530       49531               Anchovy Fillets In Olive Oil        95
# 12325       12326               Anchovy Fillets in Olive Oil        95
#
#        department_id
# 31844             11
# 23339             11
# 19941             13
# 13152             13
# 22582             15
# 24830             15
# 515               16
# ...

# %% [markdown]
# Describe brevemente tus hallazgos y lo que hiciste con ellos.
#
# Aparentemente no habia duplicados, pero si habia muchos ocultos pues tenian el mismo nombre pero unos estaban en mayusculas y otros en minusculas.

# %% [markdown]
# <div class="alert alert-block alert-success">
#
# <b>Comentario del revisor</b> <a class="tocSkip"></a>
#
# Muy bien, en este caso los productos tienen mismo nombre pero distinta ID de producto - si sacas el sum() podrias observarlo-. Siempre que tengamos duplicados, es una buena practica constatarlos (podes imprimir un head, sample o un value_counts dependiendo el caso), aqui lo mas probable es que sean productos diferentes por lo que no pareceria que sean duplicados.
# </div>

# %% [markdown]
# ### `departments` data frame

# %%
# Revisa si hay filas totalmente duplicadas
print("Filas duplicadas :", df_departments.duplicated(keep=False).sum())
# Out:
# Filas duplicadas : 0

# %%
# Revisa únicamente si hay IDs duplicadas de departamentos
n_duplicados = df_departments['department_id'].duplicated().sum()
print(f"Pedidos con department_id repetido: {n_duplicados}")
# Out:
# Pedidos con department_id repetido: 0

# %% [markdown]
# Describe brevemente tus hallazgos y lo que hiciste con ellos.
#
# No hubo duplicados

# %% [markdown]
# ### `aisles` data frame

# %%
# Revisa si hay filas totalmente duplicadas
print("Filas duplicadas :", df_aisles.duplicated(keep=False).sum())
# Out:
# Filas duplicadas : 0

# %%
# Revisa únicamente si hay IDs duplicadas de pasillos
n_duplicados = df_aisles['aisle_id'].duplicated().sum()
print(f"Pedidos con aisle_id repetido: {n_duplicados}")
# Out:
# Pedidos con aisle_id repetido: 0

# %% [markdown]
# Describe brevemente tus hallazgos y lo que hiciste con ellos.
#
# No hubo duplicados

# %% [markdown]
# ### `order_products` data frame

# %%
# Revisa si hay filas totalmente duplicadas
print("Filas duplicadas :", df_order_products.duplicated(keep=False).sum())
# Out:
# Filas duplicadas : 0

# %%
# Vuelve a verificar si hay cualquier otro duplicado engañoso
n_duplicados = df_order_products.duplicated(subset=['order_id','product_id']).sum()
print(f"Duplicados por (order_id, product_id): {n_duplicados}")
# Out:
# Duplicados por (order_id, product_id): 0

# %% [markdown]
# Describe brevemente tus hallazgos y lo que hiciste con ellos.
#
# No hay duplicados

# %% [markdown]
# <div class="alert alert-block alert-success">
#
# <b>Comentario del revisor</b> <a class="tocSkip"></a>
#
# Buena seccion.
# </div>

# %% [markdown]
# ## Encuentra y elimina los valores ausentes
#
# Al trabajar con valores duplicados, pudimos observar que también nos falta investigar valores ausentes:
#
# * La columna `'product_name'` de la tabla products.
# * La columna `'days_since_prior_order'` de la tabla orders.
# * La columna `'add_to_cart_order'` de la tabla order_productos.

# %% [markdown]
# ### `products` data frame

# %%
# Encuentra los valores ausentes en la columna 'product_name'
n_nulls = df_products['product_name'].isnull().sum()
print(f"Cantidad de productos sin nombre: {n_nulls}")
# Out:
# Cantidad de productos sin nombre: 1258

# %% [markdown]
# Describe brevemente cuáles son tus hallazgos.
# hay 1258 productos sin nombre

# %%
#  ¿Todos los nombres de productos ausentes están relacionados con el pasillo con ID 100?
mask_null = df_products['product_name'].isnull()
aisles_null = df_products.loc[mask_null, 'aisle_id'].unique()

print("Aisle IDs para productos sin nombre:", aisles_null)
# Out:
# Aisle IDs para productos sin nombre: [100]

# %% [markdown]
# Describe brevemente cuáles son tus hallazgos.
#
# Efectivamente

# %%
# ¿Todos los nombres de productos ausentes están relacionados con el departamento con ID 21?
departments_null = df_products.loc[mask_null, 'department_id'].unique()
print("Department IDs para productos sin nombre:", departments_null)
# Out:
# Department IDs para productos sin nombre: [21]

# %% [markdown]
# Describe brevemente cuáles son tus hallazgos.
# Si, asi es.

# %%
# Usa las tablas department y aisle para revisar los datos del pasillo con ID 100 y el departamento con ID 21.
depasle = df_products[(df_products['aisle_id']==100) & (df_products['department_id']==21)]
print(depasle)
# Out:
#        product_id product_name  aisle_id  department_id
# 37             38          NaN       100             21
# 71             72          NaN       100             21
# 109           110          NaN       100             21
# 296           297          NaN       100             21
# 416           417          NaN       100             21
# ...           ...          ...       ...            ...
# 49552       49553          NaN       100             21
# 49574       49575          NaN       100             21
# 49640       49641          NaN       100             21
# 49663       49664          NaN       100             21
# 49668       49669          NaN       100             21
#
# [1258 rows x 4 columns]

# %% [markdown]
# Describe brevemente cuáles son tus hallazgos.
# Hay 1258 filas con estos dos campos aisle_id y department_id repetidos, y con el product_name en NaN

# %%
# Completa los nombres de productos ausentes con 'Unknown'
df_products['product_name'] = df_products['product_name'].fillna('Unknown')
print("Productos sin nombre:", df_products['product_name'].isnull().sum())
# Out:
# Productos sin nombre: 0

# %% [markdown]
# Describe brevemente tus hallazgos y lo que hiciste con ellos.
# Listo, ya fueron llenados con 'Unknown'

# %% [markdown]
# <div class="alert alert-block alert-success">
#
# <b>Comentario del revisor</b> <a class="tocSkip"></a>
#
# Excelente econtrando el patron de estos nulos.
# </div>

# %% [markdown]
# ### `orders` data frame

# %%
# Encuentra los valores ausentes
print(df_instacart_orders.isnull().sum())
# Out:
# order_id                      0
# user_id                       0
# order_number                  0
# order_dow                     0
# order_hour_of_day             0
# days_since_prior_order    28817
# dtype: int64

# %%
# ¿Hay algún valor ausente que no sea el primer pedido del cliente?
missing_not_first = (
    df_instacart_orders['days_since_prior_order'].isnull() &
    (df_instacart_orders['order_number'] != 1)
)
print(missing_not_first.sum())
# Out:
# 0

# %% [markdown]
# Describe brevemente tus hallazgos y lo que hiciste con ellos.
#
# No, todos corresponden al primer pedido

# %% [markdown]
# <div class="alert alert-block alert-success">
#
# <b>Comentario del revisor</b> <a class="tocSkip"></a>
#
# Muy bien entendiendo la naturaleza de los nulos de este dataset.
# </div>

# %% [markdown]
# ### `order_products` data frame

# %%
# Encuentra los valores ausentes
print(df_order_products.isnull().sum())
# Out:
# order_id               0
# product_id             0
# add_to_cart_order    836
# reordered              0
# dtype: int64

# %%
# ¿Cuáles son los valores mínimos y máximos en esta columna?
min_val = df_order_products['add_to_cart_order'].min()
max_val = df_order_products['add_to_cart_order'].max()
print(f"Valor mínimo en add_to_cart_order: {min_val}")
print(f"Valor máximo en add_to_cart_order: {max_val}")
# Out:
# Valor mínimo en add_to_cart_order: 1.0
# Valor máximo en add_to_cart_order: 64.0

# %% [markdown]
# Describe brevemente cuáles son tus hallazgos.
#
# El pedido minimo a tenido un articulo y el maximo 64 articulos, asombroso.

# %%
# Guarda todas las IDs de pedidos que tengan un valor ausente en 'add_to_cart_order'
missing = df_order_products[df_order_products['add_to_cart_order'].isnull()]
print(missing)
# Out:
#          order_id  product_id  add_to_cart_order  reordered
# 737       2449164        5068                NaN          0
# 9926      1968313       43867                NaN          0
# 14394     2926893       11688                NaN          0
# 16418     1717990        4142                NaN          0
# 30114     1959075       42828                NaN          1
# ...           ...         ...                ...        ...
# 4505662   1800005        7411                NaN          0
# 4511400   1633337         260                NaN          0
# 4517562    404157        9517                NaN          0
# 4534112   1673227       17835                NaN          0
# 4535739   1832957       17949                NaN          1
#
# [836 rows x 4 columns]

# %%
# ¿Todos los pedidos con valores ausentes tienen más de 64 productos?
# Agrupa todos los pedidos con datos ausentes por su ID de pedido.
# Cuenta el número de 'product_id' en cada pedido y revisa el valor mínimo del conteo.

# IDs únicos de pedidos con posición en carrito ausente
order_ids_missing = missing['order_id'].unique()

# Filtramos el DataFrame original para esos pedidos
orders_subset = df_order_products[df_order_products['order_id'].isin(order_ids_missing)]

# Agrupamos por pedido y contamos los productos
counts = orders_subset.groupby('order_id')['product_id'].count()

# Obtenemos el conteo mínimo
min_count = counts.min()

print(f"Mínimo de productos en un pedido con add_to_cart_order ausente: {min_count}")
# Out:
# Mínimo de productos en un pedido con add_to_cart_order ausente: 65

# %% [markdown]
# <div class="alert alert-block alert-warning">
# <b>Comentario del revisor </b> <a class="tocSkip"></a>
#
# En razon de la pregunta si `¿Todos los pedidos con valores ausentes tienen más de 64 productos?`
#
# Podes buscar las `order_id` que tienen valores ausentes en la columna 'add_to_cart_order'.
#
# Después de identificar los IDs -unicos- de pedidos con valores ausentes, asegúrate de filtrar el DataFrame original para incluir solo las filas correspondientes a esos IDs de pedidos antes de realizar la agrupación (Verifica que se encuentren en el primer filtrado los datos). Esto asegurará que estás trabajando solo con los datos relevantes. (Como consejo utiliza en la agrupacion la id de orden pero utilizando el metodo unique para depurar)
#
# Al calcular la cantidad mínima de productos, asegúrate de que estás obteniendo la cantidad mínima de productos en un solo pedido con valores ausentes, no la cantidad mínima entre todos los pedidos agrupados. Revisa cómo estás aplicando la función de conteo y la función de mínimo para obtener el resultado correcto.
# </div>
#
#
# <div class="alert alert-block alert-success">
#
# <b>Comentario del revisor #2</b> <a class="tocSkip"></a>
#
# Corregido, ien hecho.
# </div>

# %% [markdown]
# Describe brevemente cuáles son tus hallazgos.
# <div class="alert alert-block alert-info">
# <b>Respuesta del estudiante</b> <a class="tocSkip"></a>
#
# Gracias, no habia entendido bien.
# Todos los pedidos con valores ausentes tienen mas de 64 productos wow
# </div>

# %%
# Remplaza los valores ausentes en la columna 'add_to_cart? con 999 y convierte la columna al tipo entero.
df_order_products['add_to_cart_order'] = df_order_products['add_to_cart_order'].fillna(999).astype(int)
print(df_order_products['add_to_cart_order'].dtype)
print("Nulos:", df_order_products['add_to_cart_order'].isnull().sum())
# Out:
# int64
# Nulos: 0

# %% [markdown]
# Describe brevemente tus hallazgos y lo que hiciste con ellos.
# Rellenamos los datos nulos con 999 para que porlomenos tengan un valor arbitriario que ignoraremos despues en el analisis pero porlomientras ya podemos transformar esa columna a tipo entero.
# <div class="alert alert-block alert-info">
# <b>Respuesta del estudiante</b> <a class="tocSkip"></a>
#
# Tal vez sea el numero maximo de articulos que un usuario puede añadir en su carrito dentro de la aplicacion o tal vez la empresa lo puso como un limite para la carga que se le puede llevar a un usuario, es esto o tal vez simplemente nadie a hecho un pedido con mas de 64 articulos.</div>

# %% [markdown]
# <div class="alert alert-block alert-warning">
#
# <b>Comentario del revisor</b> <a class="tocSkip"></a>
#
# ¿Por que crees que el maximo de `add_to_cart_order` se detiene en 64? ¿No crees que es un valor muy arbitrario?</div>
#
#
#
# <div class="alert alert-block alert-success">
#
# <b>Comentario del revisor #2</b> <a class="tocSkip"></a>
#
# Corregido, como bien decis es probable que sea un limite (int64) por un error.
# </div>

# %% [markdown]
# ## Conclusiones
#
# Escribe aquí tus conclusiones intermedias sobre el Paso 2. Preprocesamiento de los datos
#
# Con lo que hicimos ahora no tenemos duplicados, ni nulos por lo que podemos avanzar en el analisis con una base de conocimiento mas uniforme en la cual podemos hacer operaciones, tambien podemos hacer los graficos correspondientes para analizar los datos e ir buscando algunas correlaciones e insights.

# %% [markdown]
# # Paso 3. Análisis de los datos
#
# Una vez los datos estén procesados y listos, haz el siguiente análisis:

# %% [markdown]
# # [A] Fácil (deben completarse todos para aprobar)
#
# 1. Verifica que los valores en las columnas `'order_hour_of_day'` y `'order_dow'` en la tabla orders sean razonables (es decir, `'order_hour_of_day'` oscile entre 0 y 23 y `'order_dow'` oscile entre 0 y 6).
# 2. Crea un gráfico que muestre el número de personas que hacen pedidos dependiendo de la hora del día.
# 3. Crea un gráfico que muestre qué día de la semana la gente hace sus compras.
# 4. Crea un gráfico que muestre el tiempo que la gente espera hasta hacer su siguiente pedido, y comenta sobre los valores mínimos y máximos.

# %% [markdown]
# ### [A1] Verifica que los valores sean sensibles

# %% [markdown]
# <div class="alert alert-block alert-danger">
# <b>Comentario del revisor </b> <a class="tocSkip"></a>
#
# Siguiendo las buenas practicas importa matplotlib en la celda del inicio (del  proyecto) -donde importaste pandas- y dedicala exclusivamente a la importacion de librerias.
#
# Esteo es importante por varios puntos
#
# - Tener todas las importaciones en un solo lugar facilita la lectura y comprensión del código, si yo al abrir un proyecto veo las librerias se de que va a ir el trabajo (por ejemplo si importa matplotlib habra graficos)
# - Otro beneficio es la detección temprana de errores ya que importar todas las librerías al inicio permite detectar errores de importación (como bibliotecas faltantes o incompatibilidades) antes de ejecutar cualquier linea de codigo.
#
# </div>
#
# <div class="alert alert-block alert-success">
#
# <b>Comentario del revisor #2</b> <a class="tocSkip"></a>
#
# Corregido,.
# </div>

# %% [markdown]
# <div class="alert alert-block alert-info">
# <b>Respuesta del estudiante</b> <a class="tocSkip"></a>
#
# Corregido, gracias.
# </div>

# %%
# 1. Verificar rangos de valores
print("order_hour_of_day:", df_instacart_orders['order_hour_of_day'].min(), "a", df_instacart_orders['order_hour_of_day'].max())
print("order_dow:", df_instacart_orders['order_dow'].min(), "a", df_instacart_orders['order_dow'].max())

print("\nFrecuencia por hora del día:")
print(df_instacart_orders['order_hour_of_day']
      .value_counts()
      .sort_index())

# Frecuencia de cada día
print("\nFrecuencia por día de la semana:")
print(df_instacart_orders['order_dow']
      .value_counts()
      .sort_index())
# Out:
# order_hour_of_day: 0 a 23
# order_dow: 0 a 6
#
# Frecuencia por hora del día:
# 0      3180
# 1      1763
# 2       989
# 3       770
# 4       765
# 5      1371
# 6      4215
# 7     13043
# 8     25024
# 9     35896
# 10    40578
# 11    40032
# 12    38034
# 13    39007
# 14    39631
# 15    39789
# 16    38112
# 17    31930
# 18    25510
# 19    19547
# 20    14624
# 21    11019
# 22     8512
# 23     5611
# Name: order_hour_of_day, dtype: int64
#
# Frecuencia por día de la semana:
# 0    84090
# 1    82185
# 2    65833
# 3    60897
# 4    59810
# 5    63488
# 6    62649
# Name: order_dow, dtype: int64

# %% [markdown]
# <div class="alert alert-block alert-danger">
# <b>Comentario del revisor</b> <a class="tocSkip"></a>
#
# En este caso estas observando los valores minimos y maximos, sin saber cuales son los valores medios.
#
# Constatando los valores unicos observaremos el panorama completo ya que de esta forma no podemos ver si los valores medios son congruentes.</div>
#
# <div class="alert alert-block alert-info">
# <b>Respuesta del estudiante</b> <a class="tocSkip"></a>
#
# Gracias no recordaba bien como usar el value_counts ni para que era util.</div>
#
# <div class="alert alert-block alert-success">
#
# <b>Comentario del revisor #2</b> <a class="tocSkip"></a>
#
# Corregido
# </div>

# %% [markdown]
# Al parecer si, los valores de los dias solo oscilan entre 0 y 6 osea de domingo a sabado y las horas tambien estan bien de 0 a 23 horas, no hubo errores al registrar los datos.

# %% [markdown]
# <div class="alert alert-block alert-danger">
#
# <b>Comentario del revisor</b> <a class="tocSkip"></a>
#
# Recorda dejar tus conclusiones sobre esta extracción, podes comentar acerca de lo donde se produce el común de los resultados.</div>
#
# <div class="alert alert-block alert-info">
# <b>Respuesta del estudiante</b> <a class="tocSkip"></a>
#
# Llenado, gracias.
# </div>
#
# <div class="alert alert-block alert-success">
#
# <b>Comentario del revisor #2</b> <a class="tocSkip"></a>
#
# Corregido.
# </div>

# %% [markdown]
# ### [A2] Para cada hora del día, ¿cuántas personas hacen órdenes?

# %%
orders_by_hour = df_instacart_orders.groupby('order_hour_of_day')['order_id'].count()
orders_by_hour.plot(kind='bar', xlabel='Hora del día', ylabel='Número de pedidos', title='Pedidos por hora del día' )
plt.show()

# %% [markdown]
# Tiene sentido la grafica, en la noche muy pocas personas hacen pedidos, en la mañana entre las 9 y las 4 de la tarde es cuando se hacen mas pedidos llegando hasta los 40 mil pedidos.

# %% [markdown]
# <div class="alert alert-block alert-success">
#
# <b>Comentario del revisor</b> <a class="tocSkip"></a>
#
# Buen grafico.
# </div>

# %% [markdown]
# ### [A3] ¿Qué día de la semana compran víveres las personas?

# %%
orders_by_dow = df_instacart_orders.groupby('order_dow')['order_id'].count()
orders_by_dow.plot(kind='bar', title='Pedidos por día de la semana', xlabel='Día de la semana (0=Domingo)', ylabel='Número de pedidos')
plt.show()

# %% [markdown]
# Entre el martes y el sabado la venta ronda entre los 60000 mil pedidos mientras que domingo y lunes hay una venta mayor rondando los 80000 mil.

# %% [markdown]
# <div class="alert alert-block alert-success">
#
# <b>Comentario del revisor</b> <a class="tocSkip"></a>
#
# Muy bien.
#
# </div>

# %% [markdown]
# ### [A4] ¿Cuánto tiempo esperan las personas hasta hacer otro pedido? Comenta sobre los valores mínimos y máximos.

# %%
df_instacart_orders['days_since_prior_order'].plot(kind='hist', title='Distribución del tiempo entre pedidos', bins=30)
plt.show()
print("Tiempo minimo entre pedidos:", int(df_instacart_orders['days_since_prior_order'].min()), "dias")
print("Tiempo maximo entre pedidos:", int(df_instacart_orders['days_since_prior_order'].max()), "dias")
# Out:
# Tiempo minimo entre pedidos: 0 dias
# Tiempo maximo entre pedidos: 30 dias

# %% [markdown]
# Escribe aquí tus conclusiones
#
# Alrededor de 10000 mil personas compran otra vez ese mismo dia, mientras que mas de 50000 mil esperan al rededor de 30 dias un mes para hacer otra compra, es curioso porque yo creia que iba a haber muchas compas al rededor de los 15 dias por las quincenas y los dias de paga, pero noto que si hay alrededor del septimo dia cada semana porlomenos alredor de 45 mil personas compran algo.

# %% [markdown]
# <div class="alert alert-block alert-success">
#
# <b>Comentario del revisor</b> <a class="tocSkip"></a>
#
# Excelentes conclusiones.
# </div>

# %% [markdown]
# # [B] Intermedio (deben completarse todos para aprobar)
#
# 1. ¿Existe alguna diferencia entre las distribuciones `'order_hour_of_day'` de los miércoles y los sábados? Traza gráficos de barra de `'order_hour_of_day'` para ambos días en la misma figura y describe las diferencias que observes.
# 2. Grafica la distribución para el número de órdenes que hacen los clientes (es decir, cuántos clientes hicieron solo 1 pedido, cuántos hicieron 2, cuántos 3, y así sucesivamente...).
# 3. ¿Cuáles son los 20 principales productos que se piden con más frecuencia (muestra su identificación y nombre)?

# %% [markdown]
# ### [B1] Diferencia entre miércoles y sábados para  `'order_hour_of_day'`. Traza gráficos de barra para los dos días y describe las diferencias que veas.

# %%
df_instacart_orders[df_instacart_orders['order_dow']==3]['order_hour_of_day'].plot(kind='hist', bins=20)
df_instacart_orders[df_instacart_orders['order_dow']==6]['order_hour_of_day'].plot(kind='hist', bins=20, alpha=0.8)
plt.legend(['Miercoles', 'Sabado'])
plt.show()

# %% [markdown]
# A las 15 horas hay un pico de ventas
#
# tiene sentido ya que es antes de la hora de la comida de muchas personas.
#
# De las 7 a las 17 horas es cuando mas pedidos hacen.

# %% [markdown]
# <div class="alert alert-block alert-success">
#
# <b>Comentario del revisor</b> <a class="tocSkip"></a>
#
# Muy buen grafico, queda muy clara la diferencia. En estos casos, utilizar un grafico de barras hara que quede mas claro aun.
#
# </div>

# %% [markdown]
# ### [B2] ¿Cuál es la distribución para el número de pedidos por cliente?

# %%
orders_by_client = df_instacart_orders.groupby(by='user_id')['order_id'].count()
orders_by_client.plot(kind='hist', title='Distribución de pedidos por cliente' ,bins=30)
# Out:
# <AxesSubplot:title={'center':'Distribución de pedidos por cliente'}, ylabel='Frequency'>

# %%
plt.show()

# %% [markdown]
# En el eje X tenemos el numero de pedidos por un cliente, podemos notar como la mayoria de los usuarios realizan pocos pedidos de 1 a 3 mientras que algunos clientes mas activos realizan de 10 a 15

# %% [markdown]
# <div class="alert alert-block alert-success">
#
# <b>Comentario del revisor</b> <a class="tocSkip"></a>
#
# Buena extraccion.
# </div>

# %% [markdown]
# ### [B3] ¿Cuáles son los 20 productos más populares (muestra su ID y nombre)?

# %%
orders_per_product = df_order_products.groupby('product_id')['order_id'].count().rename('order_count').reset_index()

# %%
top20 = orders_per_product.sort_values('order_count', ascending=False).head(20)

# %%
top20 = top20.merge(
    df_products[['product_id','product_name']],
    on='product_id',
    how='left'
)

print(top20)
# Out:
#     product_id  order_count              product_name
# 0        24852        66050                    Banana
# 1        13176        53297    Bag of Organic Bananas
# 2        21137        37039      Organic Strawberries
# 3        21903        33971      Organic Baby Spinach
# 4        47209        29773      Organic Hass Avocado
# 5        47766        24689           Organic Avocado
# 6        47626        21495               Large Lemon
# 7        16797        20018              Strawberries
# 8        26209        19690                     Limes
# 9        27845        19600        Organic Whole Milk
# 10       27966        19197       Organic Raspberries
# 11       22935        15898      Organic Yellow Onion
# 12       24964        15292            Organic Garlic
# 13       45007        14584          Organic Zucchini
# 14       39275        13879       Organic Blueberries
# 15       49683        13675            Cucumber Kirby
# ...

# %%
top20.plot(kind='bar', x='product_name', y='order_count' , rot=90, xlabel='Nombre del producto', ylabel='Numero de pedidos', legend=None, title='Top 20 Productos mas populares')
plt.show()

# %% [markdown]
# <div class="alert alert-block alert-warning">
# <b>Comentario del revisor</b> <a class="tocSkip"></a>
#
# Recorda que en este caso le agregaria valor graficar ese top 20 con un grafico de barras. Tener a mano el grafico hara mas amena y legible la experiencia del cliente. Ordenar los valores hara que la extraccion sea aun mas clara.</div>
#
# <div class="alert alert-block alert-info">
# <b>Respuesta del estudiante</b> <a class="tocSkip"></a>
#
# gracias por el consejo.
# </div>
#
# <div class="alert alert-block alert-success">
#
# <b>Comentario del revisor #2</b> <a class="tocSkip"></a>
#
# Corregido, buen grafico.
# </div>

# %% [markdown]
# Al parecer las frutas y verduras son los productos mas vendidos, en especial las bananas!!!.

# %% [markdown]
# # [C] Difícil (deben completarse todos para aprobar)
#
# 1. ¿Cuántos artículos suelen comprar las personas en un pedido? ¿Cómo es la distribución?
# 2. ¿Cuáles son los 20 principales artículos que vuelven a pedirse con mayor frecuencia (muestra sus nombres e IDs de los productos)?
# 3. Para cada producto, ¿cuál es la tasa de repetición del pedido (número de repeticiones de pedido/total de pedidos?
# 4. Para cada cliente, ¿qué proporción de los productos que pidió ya los había pedido? Calcula la tasa de repetición de pedido para cada usuario en lugar de para cada producto.
# 5. ¿Cuáles son los 20 principales artículos que la gente pone primero en sus carritos (muestra las IDs de los productos, sus nombres, y el número de veces en que fueron el primer artículo en añadirse al carrito)?

# %% [markdown]
# ### [C1] ¿Cuántos artículos compran normalmente las personas en un pedido? ¿Cómo es la distribución?

# %%
items_per_order = df_order_products.groupby('order_id')['product_id'].count()

# %%
print("Estadísticas de artículos por pedido:")
print(items_per_order.describe())
# Out:
# Estadísticas de artículos por pedido:
# count    450046.000000
# mean         10.098983
# std           7.540206
# min           1.000000
# 25%           5.000000
# 50%           8.000000
# 75%          14.000000
# max         127.000000
# Name: product_id, dtype: float64

# %%
items_per_order.plot(kind='hist', title='Distribución de artículos por pedido' ,bins=40)
plt.show()

# %%
items_upto_40 = items_per_order[items_per_order <= 40]

(items_upto_40.value_counts()
               .sort_index()
               .plot(kind='bar'))
plt.xlabel('Número de artículos por pedido')
plt.ylabel('Número de pedidos')
plt.title('Frecuencia de artículos por pedido (1–40 artículos)')
plt.tight_layout()
plt.show()

# %% [markdown]
# <div class="alert alert-block alert-warning">
# <b>Comentario del revisor</b> <a class="tocSkip"></a>
#
# Esta perfecto el grafico, como consejo podrias graficar  (en otra celda) el top 30 o 40 para visualizar mejor los datos ya que a partir de alli practicamente no tenemos informacion.</div>
#
# <div class="alert alert-block alert-info">
# <b>Respuesta del estudiante</b> <a class="tocSkip"></a>
#
# gracias ahora se ve mas clara la distribucion.
# </div>
#
# <div class="alert alert-block alert-success">
#
# <b>Comentario del revisor #2</b> <a class="tocSkip"></a>
#
# Corregido.
# </div>

# %% [markdown]
# Entre 70mil y 100mil usuarios compran de uno a 10 articulos por pedido, tiene sentido ya que la gente cuando va al mercado compran variedad de frutas y verduras para su comida.

# %% [markdown]
# ### [C2] ¿Cuáles son los 20 principales artículos que vuelven a pedirse con mayor frecuencia (muestra sus nombres e IDs de los productos)?

# %%
reorders = df_order_products[df_order_products['reordered'] == 1]

# %%
reorder_counts = (
    reorders
    .groupby('product_id')
    .size()                     # cuenta filas por product_id
    .reset_index(name='reorder_count')  # convierte Series a DataFrame
)

# %%
top20_reorders = reorder_counts.sort_values(by='reorder_count', ascending=False).head(20)

# %%
top20_reorders = pd.merge(
    top20_reorders, 
    df_products[['product_id', 'product_name']],
    on='product_id',
    how='left'
)
print(top20_reorders)
# Out:
#     product_id  reorder_count              product_name
# 0        24852          55763                    Banana
# 1        13176          44450    Bag of Organic Bananas
# 2        21137          28639      Organic Strawberries
# 3        21903          26233      Organic Baby Spinach
# 4        47209          23629      Organic Hass Avocado
# 5        47766          18743           Organic Avocado
# 6        27845          16251        Organic Whole Milk
# 7        47626          15044               Large Lemon
# 8        27966          14748       Organic Raspberries
# 9        16797          13945              Strawberries
# 10       26209          13327                     Limes
# 11       22935          11145      Organic Yellow Onion
# 12       24964          10411            Organic Garlic
# 13       45007          10076          Organic Zucchini
# 14       49683           9538            Cucumber Kirby
# 15       28204           8989        Organic Fuji Apple
# ...

# %%
top20_reorders.plot(kind='bar', x='product_name', y='reorder_count' , rot=90, xlabel='Nombre del producto', ylabel='Numero de reordenes', legend=None, title='Top 20 Productos mas recomprados')
plt.show()

# %% [markdown]
# <div class="alert alert-block alert-warning">
# <b>Comentario del revisor</b> <a class="tocSkip"></a>
#
# Recorda que en este caso le agregaria valor graficar ese top 20 con un grafico de barras. Tener a mano el grafico hara mas amena y legible la experiencia del cliente. Ordenar los valores hara que la extraccion sea aun mas clara.</div>
#
# <div class="alert alert-block alert-info">
# <b>Respuesta del estudiante</b> <a class="tocSkip"></a>
#
# Ciertamente se entiende mejor.
# </div>
#
# <div class="alert alert-block alert-success">
#
# <b>Comentario del revisor #2</b> <a class="tocSkip"></a>
#
# Corregido.
# </div>

# %% [markdown]
# Los resultados son muy parecidos a los que obtuvimos cuando filtramos los 20 productos mas populares, al parecer otra vez las Bananas se llevan la mejor parte y son los mas reordenados.

# %% [markdown]
# ### [C3] Para cada producto, ¿cuál es la proporción de las veces que se pide y que se vuelve a pedir?

# %%
total_pedidos = (
    df_order_products
    .groupby('product_id')
    .size()
    .reset_index(name='total_count')
)

# %%
reorder_counts = (
    df_order_products[df_order_products['reordered'] == 1]
    .groupby('product_id')
    .size()
    .reset_index(name='reorder_count')
)

# %%
df_combinado = total_pedidos.merge(
    reorder_counts,
    on='product_id',
    how='left'
)

df_combinado['reorder_proportion'] = df_combinado['reorder_count'] / df_combinado['total_count']

df_combinado = df_combinado.merge(
    df_products[['product_id', 'product_name']],
    on='product_id',
    how='left'
)

print(df_combinado.head(10))
# Out:
#    product_id  total_count  reorder_count  reorder_proportion  \
# 0           1          280          158.0            0.564286
# 1           2           11            NaN                 NaN
# 2           3           42           31.0            0.738095
# 3           4           49           25.0            0.510204
# 4           7            2            1.0            0.500000
# 5           8           19            6.0            0.315789
# 6           9           21           16.0            0.761905
# 7          10          337          151.0            0.448071
# 8          11           16           10.0            0.625000
# 9          12           41           16.0            0.390244
#
#                                         product_name
# 0                         Chocolate Sandwich Cookies
# 1                                   All-Seasons Salt
# 2               Robust Golden Unsweetened Oolong Tea
# 3  Smart Ones Classic Favorites Mini Rigatoni Wit...
# ...

# %% [markdown]
# Algunos productos presentan proporciones muy altas (por ejemplo, el té Oolong product_id = 3 con ~0.74, y el yogurt de fresa/arándano product_id = 9 con ~0.76). Esto sugiere que quienes prueban esos ítems tienden a repetirlos con frecuencia.
#
# Productos con alta proporción de reorden y alto volumen (p. ej. bananas orgánicas, yogur, jugos) son candidatos clave para campañas de fidelización o recordatorios automáticos.
#
# Por el contrario, productos como los  “Sparkling Orange Juice” (id = 4) tienen proporción ~0.448071, indicando que ni la mitad de quienes lo compran regresan por más.
#
# Ítems con baja proporción a pesar de volumen moderado podrían requerir promociones o empaques diferentes para incentivar la recompra.

# %% [markdown]
# <div class="alert alert-block alert-success">
#
# <b>Comentario del revisor</b> <a class="tocSkip"></a>
#
# Excelente extraccion.
# </div>

# %% [markdown]
# ### [C4] Para cada cliente, ¿qué proporción de sus productos ya los había pedido?

# %%
# Fusionamos order_products con instacart_orders para añadir user_id
combinado = df_order_products.merge(
    df_instacart_orders[['order_id','user_id']],
    on='order_id',
    how='left'
)
# Ahora agrupamos por user_id
user_counts = combinado.groupby('user_id').agg(
    total_products=('product_id','count'),
    reordered_products=('reordered','sum')
).reset_index()

# %%
# Calculamos la proporcion
user_counts['reorder_proportion'] = (
    user_counts['reordered_products'] / user_counts['total_products']
)
print(user_counts.head(10))
print("\nResumen estadístico de la proporción de reorden por cliente:")
print(user_counts['reorder_proportion'].describe())
# Out:
#    user_id  total_products  reordered_products  reorder_proportion
# 0        2              26                   1            0.038462
# 1        4               2                   0            0.000000
# 2        5              12                   8            0.666667
# 3        6               4                   0            0.000000
# 4        7              14                  13            0.928571
# 5       11              15                   3            0.200000
# 6       12              12                   3            0.250000
# 7       13              23                  13            0.565217
# 8       14              61                  22            0.360656
# 9       15              13                   7            0.538462
#
# Resumen estadístico de la proporción de reorden por cliente:
# count    149626.000000
# mean          0.494853
# std           0.292685
# min           0.000000
# 25%           0.272727
# 50%           0.500000
# 75%           0.724138
# ...

# %% [markdown]
# Resumen estadístico (149 626 clientes)
#
# Media ≈ 0.495: en términos globales, alrededor de la mitad de los productos que el cliente promedio compra ya los había pedido antes.
#
# Desviación estándar ≈ 0.293: hay bastante dispersión: algunos clientes reordenan muy poco, otros casi siempre.
#
# ejemplos puntales
#
# user_id 2 tiene proporción ~0.038: de 26 artículos, solo 1 fue un reorden. Casi todo lo que compra lo hace por primera vez.
#
# user_id 7 casi llega a 0.93: compra casi siempre los mismos productos.

# %% [markdown]
# <div class="alert alert-block alert-success">
#
# <b>Comentario del revisor</b> <a class="tocSkip"></a>
#
# Muy bueno.
# </div>

# %% [markdown]
# ### [C5] ¿Cuáles son los 20 principales artículos que las personas ponen primero en sus carritos?

# %%
# Filtramos solo las entradas con posición 1 en el carrito
first_cart = df_order_products[df_order_products['add_to_cart_order'] == 1]

# Contamos cuántas veces cada product_id aparece en primera posición
first_counts = (
    first_cart
    .groupby('product_id')['order_id']
    .count()
    .rename('first_count')
    .reset_index()
)

# %%
# Tomamos los 20 más frecuentes
top20_first = first_counts.sort_values('first_count', ascending=False).head(20)

# Unimos con df_products para traer el nombre
top20_first = top20_first.merge(
    df_products[['product_id', 'product_name']],
    on='product_id',
    how='left'
)[['product_id', 'product_name', 'first_count']]

# %%
print(top20_first)
top20_first.plot(kind='bar', x='product_name', y='first_count' , rot=90, xlabel='Nombre del producto', ylabel='Puesto como primer articulo en carrito', legend=None, title='Top 20 articulos añadidos al carrito primero')
plt.show()
# Out:
#     product_id                 product_name  first_count
# 0        24852                       Banana        15562
# 1        13176       Bag of Organic Bananas        11026
# 2        27845           Organic Whole Milk         4363
# 3        21137         Organic Strawberries         3946
# 4        47209         Organic Hass Avocado         3390
# 5        21903         Organic Baby Spinach         3336
# 6        47766              Organic Avocado         3044
# 7        19660                 Spring Water         2336
# 8        16797                 Strawberries         2308
# 9        27966          Organic Raspberries         2024
# 10       44632   Sparkling Water Grapefruit         1914
# 11       49235          Organic Half & Half         1797
# 12       47626                  Large Lemon         1737
# 13         196                         Soda         1733
# 14       38689     Organic Reduced Fat Milk         1397
# ...

# %% [markdown]
# <div class="alert alert-block alert-warning">
# <b>Comentario del revisor</b> <a class="tocSkip"></a>
#
# Recorda que en este caso le agregaria valor graficar ese top 20 con un grafico de barras. Tener a mano el grafico hara mas amena y legible la experiencia del cliente. Ordenar los valores hara que la extraccion sea aun mas clara.</div>
#
# <div class="alert alert-block alert-info">
# <b>Respuesta del estudiante</b> <a class="tocSkip"></a>
#
# gracias.
# </div>
#
# <div class="alert alert-block alert-success">
#
# <b>Comentario del revisor #2</b> <a class="tocSkip"></a>
#
# Corregido.
# </div>

# %% [markdown]
# Definitivamente las bananas son las mas populares en esta tienda, asi como todo lo organico, eso es bueno para su salud de los clientes, tal vez despues podamos hacer una campaña de productos organicos compartiendo mas sobre sus beneficios, de sus procesos, involucrando agricultores y demas.

# %% [markdown]
# ### Conclusion general del proyecto:

# %%
print()

# %% [markdown]
# #### Al principio nuestro objetivo era conocer patrones de compra en Instacart
#
# Por lo cual leimos los datos e hicimos una limpieza para poder hacer un analisis exploratorio
# Trabajamos con cinco tablas relacionadas (pedidos, productos, pasillos, departamentos y artículos por pedido), normalizamos tipos, rellenamos y eliminamos nulos, quitamos duplicados para asegurar claridad en los datos y poder trabajar con ellos sin problemas.
#
# En el analisis encontramos patrones significativos como que la mayor actividad ocurre a media mañana y que los domingos y los lunes son los dias en que mas venta hay.
# Encontramos que el tiempo entre pedidos varía desde 1 día (primer pedido) hasta casi un mes (30 dias).
#
# Con respecto a los clientes
# Encontramos que la distribución de pedidos por cliente es muy sesgada (la mayoría hace pocos pedidos, unos pocos muchos), y en promedio casi el 50 % de los artículos de un cliente son reordenes.
#
# Identificamos los 20 ítems más populares, los que más se reordenan, los primeros que añaden al carrito y los más habituales en grandes volúmenes por pedido.
#
# Estos insights nos permiten tomar decisiones basadas en datos que despues se transformaran en estrategias de marketing como notificaciones de reorden, promociones en horas bajar, esto tambien nos ayudara a mejorar la experiencia de usuario en la aplicacion aprovechando la fidelidad natural de ciertos productos asi como otros patrones que encontramos.

# %% [markdown]
# <div class="alert alert-block alert-success">
#
# <b>Comentario del revisor</b> <a class="tocSkip"></a>
#
# Buena conclusion general.
# </div>
